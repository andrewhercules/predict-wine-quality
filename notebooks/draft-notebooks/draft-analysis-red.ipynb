# %% [markdown]
# ## Import libraries and data

# %%
# import relevant libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# change how columns are displayed in DataFrames
pd.options.display.max_columns = 60
pd.options.display.max_colwidth = 100

# %%
# set data location
data_location = 'data/winequality-red.csv'

# import data and specify separator as semi-colon (;)
red_wine_data = pd.read_csv(data_location, sep=';', engine='python')

# %% [markdown]
# ## Explore data

# %%
# print how many rows in DataFrame
print('There are %i red wine records in the DataFrame' % (len(red_wine_data)))
# Out:
# There are 1599 red wine records in the DataFrame

# %%
# print first 5 rows of DataFrame
red_wine_data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# generate key statistics for each column
red_wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# check types of data in each column
red_wine_data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# check if any columns have missing values
red_wine_data.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
# plot bar chart showing range of quality scores
sns.set(style="whitegrid")
fig = plt.subplots(figsize=(10, 5))
ax = sns.countplot(x='quality', data=red_wine_data, palette='muted')
plt.title('Red Wine Quality Ratings')
plt.xlabel('Quality rating')
plt.ylabel('Count')
plt.show()

# %%
# generate correlation matrix for data
red_wine_data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
# plot correlation heat map
fig = plt.subplots(figsize=(10, 5))
ax = sns.heatmap(red_wine_data.corr(), linewidths=.5, cmap="YlGnBu", annot=True)
plt.title('Correlation of Red Wine Data Features')
plt.show()

# %% [markdown]
# ## Clean data

# %%
# split quality ratings into categorical bins - label in parenthesis:
# 1 - 4 = poor (0)
# 5 - 6 = average (1)
# 7 - 10 = good (2)

bins = [1,4,6,10]

quality_labels=[0,1,2]

red_wine_data['quality_category'] = pd.cut(red_wine_data['quality'], bins=bins, labels=quality_labels, include_lowest=True)

red_wine_data['quality_category'].value_counts()
# Out:
# 1    1319
# 2     217
# 0      63
# Name: quality_category, dtype: int64

# %% [markdown]
# ## Build prediction models (version 1)

# %%
# import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB

# %%
# set features and labels (wine_quality)
features = red_wine_data.drop(['quality', 'quality_category'], axis=1)
wine_quality = red_wine_data['quality_category']

# split data into training and test sets
train_data, test_data, train_labels, test_labels = train_test_split(features, wine_quality, test_size=0.2, random_state=25)

# %%
# create list to store data about the performance of each model
results = []

# create list of models
models = [
    SVC(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    GaussianNB()
]

# iterate through list of models and run predictions and store accuracy values
for model in models:
    result = {}
    classifier_name = model.__class__.__name__
    kfold = KFold(n_splits=10, random_state=25)
    cross_val_results = cross_val_score(model, train_data, train_labels, cv=kfold, scoring='accuracy')
    result['classifier_name'] = classifier_name
    result['classifier_results'] = cross_val_results
    results_message = "Accuracy of %s: %0.2f (+/- %0.2f)" % (classifier_name, cross_val_results.mean(), cross_val_results.std())
    print(results_message)

print('***** Running cross_val_score on all data after creating model and fitting with training data')

for model in models:
    result = {}
    classifier_name = model.__class__.__name__
    model.fit(train_data, train_labels)
    kfold = KFold(n_splits=10, random_state=25)
    cross_val_results = cross_val_score(model, features, wine_quality, cv=kfold, scoring='accuracy')
    result['classifier_name'] = classifier_name
    result['classifier_results'] = cross_val_results
    results_message = "Accuracy of %s: %0.2f (+/- %0.2f)" % (classifier_name, cross_val_results.mean(), cross_val_results.std())
    print(results_message)
# Out:
# Accuracy of SVC: 0.81 (+/- 0.02)
# Accuracy of DecisionTreeClassifier: 0.82 (+/- 0.03)
# Accuracy of KNeighborsClassifier: 0.80 (+/- 0.02)
# Accuracy of RandomForestClassifier: 0.85 (+/- 0.03)
# Accuracy of GradientBoostingClassifier: 0.85 (+/- 0.03)
# Accuracy of GaussianNB: 0.77 (+/- 0.04)
# ***** Running cross_val_score on all data after creating model and fitting with training data
# Accuracy of SVC: 0.83 (+/- 0.07)
# Accuracy of DecisionTreeClassifier: 0.75 (+/- 0.06)
# Accuracy of KNeighborsClassifier: 0.81 (+/- 0.07)
# Accuracy of RandomForestClassifier: 0.81 (+/- 0.08)
# Accuracy of GradientBoostingClassifier: 0.83 (+/- 0.05)
# Accuracy of GaussianNB: 0.78 (+/- 0.06)

# %% [markdown]
# ## Build prediction models (version 2)

# %%
# set features and labels (wine_quality)
list_of_features = [
    'alcohol',
    'sulphates',
    'citric acid',
    'fixed acidity',
]
features = red_wine_data[list_of_features]
wine_quality = red_wine_data['quality_category']

# scale features
from sklearn.preprocessing import scale
scaled_features = scale(features, axis=0)

# split data into training and test sets
train_data, test_data, train_labels, test_labels = train_test_split(scaled_features, wine_quality, test_size=0.2, random_state=25)

# %%
# create list to store data about the performance of each model
results = []

# create list of models
models = [
    SVC(),
    DecisionTreeClassifier(),
    KNeighborsClassifier(),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    GaussianNB()
]

# iterate through list of models and run predictions and store accuracy values
for model in models:
    result = {}
    classifier_name = model.__class__.__name__
    kfold = KFold(n_splits=10, random_state=25)
    cross_val_results = cross_val_score(model, train_data, train_labels, cv=kfold, scoring='accuracy')
    result['classifier_name'] = classifier_name
    result['classifier_results'] = cross_val_results
    results_message = "Accuracy of %s: %0.2f (+/- %0.2f)" % (classifier_name, cross_val_results.mean(), cross_val_results.std())
    print(results_message)

print('***** Running cross_val_score on all data after creating model and fitting with training data')

for model in models:
    result = {}
    classifier_name = model.__class__.__name__
    model.fit(train_data, train_labels)
    kfold = KFold(n_splits=10, random_state=25)
    cross_val_results = cross_val_score(model, features, wine_quality, cv=kfold, scoring='accuracy')
    result['classifier_name'] = classifier_name
    result['classifier_results'] = cross_val_results
    results_message = "Accuracy of %s: %0.2f (+/- %0.2f)" % (classifier_name, cross_val_results.mean(), cross_val_results.std())
    print(results_message)
# Out:
# Accuracy of SVC: 0.84 (+/- 0.03)
# Accuracy of DecisionTreeClassifier: 0.80 (+/- 0.04)
# Accuracy of KNeighborsClassifier: 0.84 (+/- 0.03)
# Accuracy of RandomForestClassifier: 0.85 (+/- 0.03)
# Accuracy of GradientBoostingClassifier: 0.84 (+/- 0.02)
# Accuracy of GaussianNB: 0.82 (+/- 0.03)
# ***** Running cross_val_score on all data after creating model and fitting with training data
# Accuracy of SVC: 0.83 (+/- 0.07)
# Accuracy of DecisionTreeClassifier: 0.74 (+/- 0.06)
# Accuracy of KNeighborsClassifier: 0.81 (+/- 0.05)
# Accuracy of RandomForestClassifier: 0.81 (+/- 0.06)
# Accuracy of GradientBoostingClassifier: 0.83 (+/- 0.05)
# Accuracy of GaussianNB: 0.82 (+/- 0.07)
